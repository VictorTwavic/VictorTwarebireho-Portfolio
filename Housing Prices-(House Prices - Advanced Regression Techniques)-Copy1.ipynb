# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline
print('Done!')
# Out:
# Done!

# %%
housing_train_data = pd.read_csv('C:\\Users\\Auditor\\Desktop\\Victor\\New folder\\Data Science\\Projects\\House Prices - Advanced Regression Techniques\\Train.csv')

# %%
housing_test_data = pd.read_csv('C:\\Users\\Auditor\\Desktop\\Victor\\New folder\\Data Science\\Projects\\House Prices - Advanced Regression Techniques\\Test.csv')

# %%
housing_train_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housing_test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
housing_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
#We are going to create a pipeline that in one go: fills null values, drops unwanted columns and gets dummies/ one_hot_encoder

# %%
#Changing all null numeric values to mean

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class MultipleColumnImputerMean(BaseEstimator, TransformerMixin):
    
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        self.imputer = SimpleImputer(strategy='mean')
        self.imputer.fit(X[self.columns])
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.columns] = self.imputer.transform(X_copy[self.columns])
        return X_copy

# %%
#Changing all null string values to mode

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class MultipleColumnImputerMode(BaseEstimator, TransformerMixin):
    
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        self.imputer = SimpleImputer(strategy='most_frequent')
        self.imputer.fit(X[self.columns])
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.columns] = self.imputer.transform(X_copy[self.columns])
        return X_copy

# %%
#gets dummies/ one_hot_encoder
class GetDummies(BaseEstimator, TransformerMixin):
    
    def __init__(self, column_names):
        self.column_names = column_names

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        columns = X[self.column_names]  # Extract the specified columns

        # Apply one-hot encoding to each specified column
        dummies_list = [pd.get_dummies(columns[col], prefix=col) for col in self.column_names]

        # Concatenate one-hot encoded columns with the original DataFrame and delete dummied column
        X_encoded = pd.concat([X] + dummies_list, axis=1).drop(self.column_names, axis=1)

        return X_encoded

# %%
#Feature droper

#class FeatureDropper(BaseEstimator, TransformerMixin):
    
 #   def __init__(self, columns_to_drop):
#        self.columns_to_drop = columns_to_drop
 #   
 #   def fit(self, X, y=None):
 #       return self
    
 #   def transform(self, X):
 #       return X.drop(self.columns_to_drop, axis=1, errors='ignore')

# %%
#Create a pipeline

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('MultipleColumnImputerMean', MultipleColumnImputerMean(columns=['LotFrontage', 'MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','BsmtFullBath','BsmtHalfBath','GarageYrBlt','GarageCars','GarageArea'])),
    ('MultipleColumnImputerMode', MultipleColumnImputerMode(columns=['Utilities','Condition1','Condition2','OverallQual','OverallCond','YearRemodAdd','SaleCondition', 'Utilities'])),
    ('getdummies', GetDummies(column_names=['Utilities','Condition1','Condition2','OverallQual','OverallCond','YearRemodAdd','SaleCondition', 'Utilities']))])
    #('featuredropper', FeatureDropper())])

# %%
housing_train_data = pipeline.fit_transform(housing_train_data)
# Out:
# C:\Users\Auditor\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
housing_train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour LotConfig  ... SaleCondition_Abnorml SaleCondition_AdjLand  \
# 0         Lvl    Inside  ...                     0                     0
# 1         Lvl       FR2  ...                     0                     0
# 2         Lvl    Inside  ...                     0                     0
# 3         Lvl    Corner  ...                     1                     0
# 4         Lvl       FR2  ...                     0                     0
#
#   SaleCondition_Alloca SaleCondition_Family  SaleCondition_Normal  \
# ...

# %%
column_to_move = 'SalePrice'

# Ensure the column exists in the DataFrame
if column_to_move in housing_train_data.columns:
    # Create a list of columns excluding the specified column
    other_columns = [col for col in housing_train_data.columns if col != column_to_move]
    
    # Reorder the columns placing the specified column at the end
    housing_train_data = housing_train_data[other_columns + [column_to_move]]
else:
    print(f"The column '{column_to_move}' does not exist in the DataFrame.")

# Display the DataFrame with the specified column moved to the last position
print(housing_train_data)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
housing_test_data = pipeline.fit_transform(housing_test_data)
# Out:
# C:\Users\Auditor\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
housing_test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour LotConfig  ... YearRemodAdd_2009 YearRemodAdd_2010  \
# 0         Lvl    Inside  ...                 0                 0
# 1         Lvl    Corner  ...                 0                 0
# 2         Lvl    Inside  ...                 0                 0
# 3         Lvl    Inside  ...                 0                 0
# 4         HLS    Inside  ...                 0                 0
#
#   SaleCondition_Abnorml SaleCondition_AdjLand  SaleCondition_Alloca  \
# ...

# %%
#from sklearn.preprocessing import StandardScaler

#X = housing_train_data.drop(['SalePrice'], axis=1)
#y = housing_train_data['SalePrice']

#scaler = StandardScaler()
#X_data = scaler.fit_transform(X)
#y_data = y.to_numpy()

# %%
X_train = housing_train_data.drop(['SalePrice'], axis=1)
y_train = housing_train_data['SalePrice']

# %%
X_train = X_train.select_dtypes(exclude='object')

# %%
X_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  YearBuilt  MasVnrArea  \
# 0        1          60         65.0     8450       2003       196.0
# 1        2          20         80.0     9600       1976         0.0
# 2        3          60         68.0    11250       2001       162.0
# 3        4          70         60.0     9550       1915         0.0
# 4        5          60         84.0    14260       2000       350.0
# ...    ...         ...          ...      ...        ...         ...
# 1455  1456          60         62.0     7917       1999         0.0
# 1456  1457          20         85.0    13175       1978       119.0
# 1457  1458          70         66.0     9042       1941         0.0
# 1458  1459          20         68.0     9717       1950         0.0
# 1459  1460          20         75.0     9937       1965         0.0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  Utilities_NoSeWa  \
# ...

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import GridSearchCV

# Instantiate RandomForestClassifier
#clf = RandomForestClassifier()

#param_grid = [
 #   {'n_estimators': [10, 100, 200, 500], 'max_depth': [None, 5, 10], 'min_samples_split': [2, 3, 4]}
#]

#grid_search = GridSearchCV(clf, param_grid, cv=3, scoring='accuracy', return_train_score=True)
#grid_search.fit(X_train, y_train)

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import GridSearchCV
#from sklearn.compose import ColumnTransformer
#from sklearn.preprocessing import OneHotEncoder

# Assuming X_train and y_train are your training data
# If not, replace them with your actual training data
#X_train = ...
#y_train = ...

# Identify categorical columns
#categorical_cols = X_train.select_dtypes(include=['object']).columns

# Pipeline for numerical columns (assuming other columns are numerical)
#numerical_transformer = 'passthrough'

# Pipeline for categorical columns
#categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine the transformers
#preprocessor = ColumnTransformer(
#    transformers=[
#        ('num', numerical_transformer, X_train.columns.difference(categorical_cols)),
#        ('cat', categorical_transformer, categorical_cols)
#    ])

# Apply the preprocessing to X_train
#X_train_processed = preprocessor.fit_transform(X_train)

# Instantiate RandomForestClassifier
#clf = RandomForestClassifier()

#param_grid = [
#    {'n_estimators': [10, 100, 200, 500], 'max_depth': [None, 5, 10], 'min_samples_split': [2, 3, 4]}
#]

#grid_search = GridSearchCV(clf, param_grid, cv=3, scoring='accuracy', return_train_score=True)
#grid_search.fit(X_train_processed, y_train)

# %%
housing_test_data

X_test = housing_test_data_numeric

#scaler = StandardScaler()
#X_data = scaler.fit_transform(X)
#y_data = y.to_numpy()

# %%
X_test.info()

# %%
# Calculate the mean of the entire DataFrame
overall_mean = X_test.stack().mean()

# Replace all NaN values with the overall mean
X_test = X_test.fillna(overall_mean)

# Display the DataFrame with NaN values replaced by the mean
print(X_test)

# %%
X_test.info()

# %%
X_data =

# %%
y_data

# %%
from sklearn.preprocessing import StandardScaler

X_train = housing_train_data_numeric.drop(['SalePrice'], axis=1)
y_train = housing_train_data_numeric['SalePrice']

X_test = housing_test_data_numeric

#scaler = StandardScaler()
#X_data = scaler.fit_transform(X)
#y_data = y.to_numpy()

# %%
X_train.head()

# %%
y_train.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# Print the shapes of the resulting sets (optional)
#print("X_train shape:", X_train.shape)
#print("X_test shape:", X_test.shape)
#print("y_train shape:", y_train.shape)
#print("y_test shape:", y_test.shape)

# %%
housing_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Columns: 138 entries, Id to Utilities_AllPub
# dtypes: float64(11), int64(23), uint8(104)
# memory usage: 535.9 KB

# %%
housing_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 209 entries, Id to SalePrice
# dtypes: float64(11), int64(24), object(39), uint8(135)
# memory usage: 1.0+ MB

# %%
#Identify categorical columns
categorical_cols = housing_test_data.select_dtypes(include=['object']).columns

# Pipeline for numerical columns (assuming other columns are numerical)
numerical_transformer = 'passthrough'

# Pipeline for categorical columns
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine the transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, housing_test_data.columns.difference(categorical_cols)),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Apply the preprocessing to X_train
housing_test_data = preprocessor.fit_transform(housing_test_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [165], in <cell line: 18>()
#      11 preprocessor = ColumnTransformer(
#      12     transformers=[
#      13         ('num', numerical_transformer, housing_test_data.columns.difference(categorical_cols)),
#      14         ('cat', categorical_transformer, categorical_cols)
#      15     ])
#      17 # Apply the preprocessing to X_train
# ---> 18 housing_test_data = preprocessor.fit_transform(housing_test_data)
#
# File ~\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py:672, in ColumnTransformer.fit_transform(self, X, y)
#     670 self._check_n_features(X, reset=True)
#     671 self._validate_transformers()
# --> 672 self._validate_column_callables(X)
#     673 self._validate_remainder(X)
#     675 result = self._fit_transform(X, y, _fit_transform_one)
#
# ...

# %%
housing_test_data = pipeline.fit_transform(housing_test_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [166], in <cell line: 1>()
# ----> 1 housing_test_data = pipeline.fit_transform(housing_test_data)
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:426, in Pipeline.fit_transform(self, X, y, **fit_params)
#     399 """Fit the model and transform with the final estimator.
#     400
#     401 Fits all the transformers one after the other and transform the
#    (...)
#     423     Transformed samples.
#     424 """
#     425 fit_params_steps = self._check_fit_params(**fit_params)
# --> 426 Xt = self._fit(X, y, **fit_params_steps)
#     428 last_step = self._final_estimator
#     429 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~\anaconda3\lib\site-packages\sklearn\pipeline.py:348, in Pipeline._fit(self, X, y, **fit_params_steps)
# ...

# %%
housing_test_data = housing_test_data.select_dtypes(exclude='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error as mse
from math import sqrt

# Step 2: Train the model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Step 3: Make predictions on the test set
y_pred = lr.predict(housing_test_data)

# Step 4: Calculate RMSE
rmse = sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# C:\Users\Auditor\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - Condition2_RRAe
# - Condition2_RRAn
# - Condition2_RRNn
# - Utilities_NoSeWa
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [137], in <cell line: 12>()
#       9 lr.fit(X_train, y_train)
#      11 # Step 3: Make predictions on the test set
# ---> 12 y_pred = lr.predict(housing_test_data)
#      14 # Step 4: Calculate RMSE
#      15 rmse = sqrt(mean_squared_error(y_test, y_pred))
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
# ...

# %%
housing_test_data_numeric.info()

# %%
X_test.info()

# %%
from sklearn.metrics import r2_score


r2 = r2_score(y_test, y_pred)
print(f'R-squared Score: {r2}')

# %%
lm = LinearRegression()
lm = lm.fit(X_train, y_train)
mse(lm.predict(X_train), y_train, squared=False)

# %%
housing_test_data_numeric.info()

# %%
housing_data_numeric

# %%
housing_data_numeric = housing_data_numeric.drop('SalePrice', axis=1)

# %%
housing_data_numeric.info()

# %%
column_means = housing_test_data_numeric.mean()
column_means = housing_test_data_numeric.mean()
housing_test_data_numeric = housing_test_data_numeric.fillna(column_means)
housing_test_data_numeric.info()

# %%
predictions_lm = lm.predict(housing_test_data_numeric)

# %%
predictions_lm

# %%
predictions_lm = pd.DataFrame(predictions_lm)

# %%
predictions_lm

# %%
final_df = pd.DataFrame(housing_test_data_numeric['Id'].reset_index(drop=True))
final_df['SalePrice'] = predictions_lm
final_df.to_csv('Downloads/California_Housing_Prices10.csv', index =False)
