# %%
import numpy as np
import pandas as pd
#pd.set_option('max_columns', None)
#pd.set_option('max_rows', 90)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler
from pycaret.regression import setup, compare_models
from sklearn.model_selection import KFold, cross_val_score

from catboost import CatBoostRegressor
from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

import optuna

# %%
titanic_train = pd.read_csv('C:\\Users\\Auditor\\Desktop\\Victor\\New folder\\Data Science\\Projects\\Titanic\\train.csv')

# %%
titanic_test = pd.read_csv('C:\\Users\\Auditor\\Desktop\\Victor\\New folder\\Data Science\\Projects\\Titanic\\test.csv')

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
titanic_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
target = titanic_train['Survived']
test_ids = titanic_test['PassengerId']

# %%
titanic_train1 = titanic_train.drop(['PassengerId', 'Ticket','Survived','Name'], axis=1)
titanic_test1 = titanic_test.drop(['PassengerId','Ticket','Name'], axis=1)

# %%
titanic_train1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    male  22.0      1      0   7.2500   NaN        S
# 1         1  female  38.0      1      0  71.2833   C85        C
# 2         3  female  26.0      0      0   7.9250   NaN        S
# 3         1  female  35.0      1      0  53.1000  C123        S
# 4         3    male  35.0      0      0   8.0500   NaN        S
# ..      ...     ...   ...    ...    ...      ...   ...      ...
# 886       2    male  27.0      0      0  13.0000   NaN        S
# 887       1  female  19.0      0      0  30.0000   B42        S
# 888       3  female   NaN      1      2  23.4500   NaN        S
# 889       1    male  26.0      0      0  30.0000  C148        C
# 890       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
titanic_test1
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0         3    male  34.5      0      0    7.8292   NaN        Q
# 1         3  female  47.0      1      0    7.0000   NaN        S
# 2         2    male  62.0      0      0    9.6875   NaN        Q
# 3         3    male  27.0      0      0    8.6625   NaN        S
# 4         3  female  22.0      1      1   12.2875   NaN        S
# ..      ...     ...   ...    ...    ...       ...   ...      ...
# 413       3    male   NaN      0      0    8.0500   NaN        S
# 414       1  female  39.0      0      0  108.9000  C105        C
# 415       3    male  38.5      0      0    7.2500   NaN        S
# 416       3    male   NaN      0      0    8.0500   NaN        S
# 417       3    male   NaN      1      1   22.3583   NaN        C
#
# [418 rows x 8 columns]

# %%
data1 = pd.concat([titanic_train1, titanic_test1], axis=0).reset_index(drop=True)
data1
# Out:
#       Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0          3    male  22.0      1      0    7.2500   NaN        S
# 1          1  female  38.0      1      0   71.2833   C85        C
# 2          3  female  26.0      0      0    7.9250   NaN        S
# 3          1  female  35.0      1      0   53.1000  C123        S
# 4          3    male  35.0      0      0    8.0500   NaN        S
# ...      ...     ...   ...    ...    ...       ...   ...      ...
# 1304       3    male   NaN      0      0    8.0500   NaN        S
# 1305       1  female  39.0      0      0  108.9000  C105        C
# 1306       3    male  38.5      0      0    7.2500   NaN        S
# 1307       3    male   NaN      0      0    8.0500   NaN        S
# 1308       3    male   NaN      1      1   22.3583   NaN        C
#
# [1309 rows x 8 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
data2 = data1.copy()

# %%
data2
# Out:
#       Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0          3    male  22.0      1      0    7.2500   NaN        S
# 1          1  female  38.0      1      0   71.2833   C85        C
# 2          3  female  26.0      0      0    7.9250   NaN        S
# 3          1  female  35.0      1      0   53.1000  C123        S
# 4          3    male  35.0      0      0    8.0500   NaN        S
# ...      ...     ...   ...    ...    ...       ...   ...      ...
# 1304       3    male   NaN      0      0    8.0500   NaN        S
# 1305       1  female  39.0      0      0  108.9000  C105        C
# 1306       3    male  38.5      0      0    7.2500   NaN        S
# 1307       3    male   NaN      0      0    8.0500   NaN        S
# 1308       3    male   NaN      1      1   22.3583   NaN        C
#
# [1309 rows x 8 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Sex       1309 non-null   object
#  2   Age       1046 non-null   float64
#  3   SibSp     1309 non-null   int64
#  4   Parch     1309 non-null   int64
#  5   Fare      1308 non-null   float64
#  6   Cabin     295 non-null    object
#  7   Embarked  1307 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 81.9+ KB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.base import TransformerMixin
from sklearn.base import BaseEstimator
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

#Changing all null numeric values to mean
class MultipleColumnImputerMean(BaseEstimator, TransformerMixin):
    
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        self.imputer = SimpleImputer(strategy='mean')
        self.imputer.fit(X[self.columns])
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.columns] = self.imputer.transform(X_copy[self.columns])
        return X_copy

# %%
#Changing all null string values to mode

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class MultipleColumnImputerMode(BaseEstimator, TransformerMixin):
    
    def __init__(self, columns):
        self.columns = columns
    
    def fit(self, X, y=None):
        self.imputer = SimpleImputer(strategy='most_frequent')
        self.imputer.fit(X[self.columns])
        return self
    
    def transform(self, X):
        X_copy = X.copy()
        X_copy[self.columns] = self.imputer.transform(X_copy[self.columns])
        return X_copy

# %%
#gets dummies/ one_hot_encoder
class GetDummies(BaseEstimator, TransformerMixin):
    
    def __init__(self, column_names):
        self.column_names = column_names

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        columns = X[self.column_names]  # Extract the specified columns

        # Apply one-hot encoding to each specified column
        dummies_list = [pd.get_dummies(columns[col], prefix=col) for col in self.column_names]

        # Concatenate one-hot encoded columns with the original DataFrame and delete dummied column
        X_encoded = pd.concat([X] + dummies_list, axis=1).drop(self.column_names, axis=1)

        return X_encoded

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('MultipleColumnImputerMean', MultipleColumnImputerMean(columns=['Age', 'Fare'])),
    ('MultipleColumnImputerMode', MultipleColumnImputerMode(columns=['Cabin'])),
    ('getdummies', GetDummies(column_names=['Sex','Embarked']))])

# %%
data2
# Out:
#       Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0          3    male  22.0      1      0    7.2500   NaN        S
# 1          1  female  38.0      1      0   71.2833   C85        C
# 2          3  female  26.0      0      0    7.9250   NaN        S
# 3          1  female  35.0      1      0   53.1000  C123        S
# 4          3    male  35.0      0      0    8.0500   NaN        S
# ...      ...     ...   ...    ...    ...       ...   ...      ...
# 1304       3    male   NaN      0      0    8.0500   NaN        S
# 1305       1  female  39.0      0      0  108.9000  C105        C
# 1306       3    male  38.5      0      0    7.2500   NaN        S
# 1307       3    male   NaN      0      0    8.0500   NaN        S
# 1308       3    male   NaN      1      1   22.3583   NaN        C
#
# [1309 rows x 8 columns]

# %%
data3 = pipeline.fit_transform(data2)

# %%
data3
# Out:
#       Pclass        Age  SibSp  Parch      Fare        Cabin  Sex_female  \
# 0          3  22.000000      1      0    7.2500  C23 C25 C27           0
# 1          1  38.000000      1      0   71.2833          C85           1
# 2          3  26.000000      0      0    7.9250  C23 C25 C27           1
# 3          1  35.000000      1      0   53.1000         C123           1
# 4          3  35.000000      0      0    8.0500  C23 C25 C27           0
# ...      ...        ...    ...    ...       ...          ...         ...
# 1304       3  29.881138      0      0    8.0500  C23 C25 C27           0
# 1305       1  39.000000      0      0  108.9000         C105           1
# 1306       3  38.500000      0      0    7.2500  C23 C25 C27           0
# 1307       3  29.881138      0      0    8.0500  C23 C25 C27           0
# 1308       3  29.881138      1      1   22.3583  C23 C25 C27           0
#
#       Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0            1           0           0           1
# 1            0           1           0           0
# 2            0           0           0           1
# 3            0           0           0           1
# 4            1           0           0           1
# ...        ...         ...         ...         ...
# 1304         1           0           0           1
# 1305         0           1           0           0
# 1306         1           0           0           1
# 1307         1           0           0           1
# 1308         1           1           0           0
#
# [1309 rows x 11 columns]

# %%
data3 = data3[['Pclass', 'Age', 'SibSp','Parch', 'Fare','Sex_female','Sex_male', 'Embarked_C','Embarked_Q','Embarked_S' ]]

# %%
data3
# Out:
#       Pclass        Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0          3  22.000000      1      0    7.2500           0         1
# 1          1  38.000000      1      0   71.2833           1         0
# 2          3  26.000000      0      0    7.9250           1         0
# 3          1  35.000000      1      0   53.1000           1         0
# 4          3  35.000000      0      0    8.0500           0         1
# ...      ...        ...    ...    ...       ...         ...       ...
# 1304       3  29.881138      0      0    8.0500           0         1
# 1305       1  39.000000      0      0  108.9000           1         0
# 1306       3  38.500000      0      0    7.2500           0         1
# 1307       3  29.881138      0      0    8.0500           0         1
# 1308       3  29.881138      1      1   22.3583           0         1
#
#       Embarked_C  Embarked_Q  Embarked_S
# 0              0           0           1
# 1              1           0           0
# 2              0           0           1
# 3              0           0           1
# 4              0           0           1
# ...          ...         ...         ...
# 1304           0           0           1
# 1305           1           0           0
# 1306           0           0           1
# 1307           0           0           1
# 1308           1           0           0
#
# [1309 rows x 10 columns]

# %%
#Scaling¶

#Scaling¶

scaler = StandardScaler()
scaler.fit(data3)

data4 = pd.DataFrame(scaler.transform(data3), index=data3.index, columns=data3.columns)

# %%
data4
# Out:
#         Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 0     0.841916 -0.611972  0.481288 -0.445000 -0.503595   -0.743497  0.743497
# 1    -1.546098  0.630431  0.481288 -0.445000  0.734503    1.344995 -1.344995
# 2     0.841916 -0.301371 -0.479087 -0.445000 -0.490544    1.344995 -1.344995
# 3    -1.546098  0.397481  0.481288 -0.445000  0.382925    1.344995 -1.344995
# 4     0.841916  0.397481 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# ...        ...       ...       ...       ...       ...         ...       ...
# 1304  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 1305 -1.546098  0.708081 -0.479087 -0.445000  1.461829    1.344995 -1.344995
# 1306  0.841916  0.669256 -0.479087 -0.445000 -0.503595   -0.743497  0.743497
# 1307  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 1308  0.841916  0.000000  0.481288  0.710763 -0.211473   -0.743497  0.743497
#
#       Embarked_C  Embarked_Q  Embarked_S
# 0       -0.50977    -0.32204    0.657394
# 1        1.96167    -0.32204   -1.521159
# 2       -0.50977    -0.32204    0.657394
# 3       -0.50977    -0.32204    0.657394
# 4       -0.50977    -0.32204    0.657394
# ...          ...         ...         ...
# 1304    -0.50977    -0.32204    0.657394
# 1305     1.96167    -0.32204   -1.521159
# 1306    -0.50977    -0.32204    0.657394
# 1307    -0.50977    -0.32204    0.657394
# 1308     1.96167    -0.32204   -1.521159
#
# [1309 rows x 10 columns]

# %%
#split the data

# %%
#Split Data¶

train_final = data4.loc[:titanic_train.index.max(), :].copy()
test_final = data4.loc[titanic_train.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
train_final
# Out:
#        Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 0    0.841916 -0.611972  0.481288 -0.445000 -0.503595   -0.743497  0.743497
# 1   -1.546098  0.630431  0.481288 -0.445000  0.734503    1.344995 -1.344995
# 2    0.841916 -0.301371 -0.479087 -0.445000 -0.490544    1.344995 -1.344995
# 3   -1.546098  0.397481  0.481288 -0.445000  0.382925    1.344995 -1.344995
# 4    0.841916  0.397481 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# ..        ...       ...       ...       ...       ...         ...       ...
# 886 -0.352091 -0.223721 -0.479087 -0.445000 -0.392417   -0.743497  0.743497
# 887 -1.546098 -0.844922 -0.479087 -0.445000 -0.063719    1.344995 -1.344995
# 888  0.841916  0.000000  0.481288  1.866526 -0.190364    1.344995 -1.344995
# 889 -1.546098 -0.301371 -0.479087 -0.445000 -0.063719   -0.743497  0.743497
# 890  0.841916  0.164530 -0.479087 -0.445000 -0.493927   -0.743497  0.743497
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0      -0.50977   -0.322040    0.657394
# 1       1.96167   -0.322040   -1.521159
# 2      -0.50977   -0.322040    0.657394
# 3      -0.50977   -0.322040    0.657394
# 4      -0.50977   -0.322040    0.657394
# ..          ...         ...         ...
# 886    -0.50977   -0.322040    0.657394
# 887    -0.50977   -0.322040    0.657394
# 888    -0.50977   -0.322040    0.657394
# 889     1.96167   -0.322040   -1.521159
# 890    -0.50977    3.105202   -1.521159
#
# [891 rows x 10 columns]

# %%
test_final
# Out:
#        Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 0    0.841916  0.358655 -0.479087 -0.445000 -0.492396   -0.743497  0.743497
# 1    0.841916  1.329283  0.481288 -0.445000 -0.508429    1.344995 -1.344995
# 2   -0.352091  2.494035 -0.479087 -0.445000 -0.456465   -0.743497  0.743497
# 3    0.841916 -0.223721 -0.479087 -0.445000 -0.476284   -0.743497  0.743497
# 4    0.841916 -0.611972  0.481288  0.710763 -0.406194    1.344995 -1.344995
# ..        ...       ...       ...       ...       ...         ...       ...
# 413  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 414 -1.546098  0.708081 -0.479087 -0.445000  1.461829    1.344995 -1.344995
# 415  0.841916  0.669256 -0.479087 -0.445000 -0.503595   -0.743497  0.743497
# 416  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 417  0.841916  0.000000  0.481288  0.710763 -0.211473   -0.743497  0.743497
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0      -0.50977    3.105202   -1.521159
# 1      -0.50977   -0.322040    0.657394
# 2      -0.50977    3.105202   -1.521159
# 3      -0.50977   -0.322040    0.657394
# 4      -0.50977   -0.322040    0.657394
# ..          ...         ...         ...
# 413    -0.50977   -0.322040    0.657394
# 414     1.96167   -0.322040   -1.521159
# 415    -0.50977   -0.322040    0.657394
# 416    -0.50977   -0.322040    0.657394
# 417     1.96167   -0.322040   -1.521159
#
# [418 rows x 10 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from pycaret.classification import *

s = setup(train_final, target = target)
# Out:
# <style type="text/css">
# #T_e0b63_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e0b63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0b63_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e0b63_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0b63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0b63_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e0b63_row0_col1" class="data row0 col1" >4778</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0b63_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e0b63_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0b63_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e0b63_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0b63_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e0b63_row3_col1" class="data row3 col1" >(891, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0b63_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e0b63_row4_col1" class="data row4 col1" >(891, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0b63_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e0b63_row5_col1" class="data row5 col1" >(623, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0b63_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e0b63_row6_col1" class="data row6 col1" >(268, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0b63_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e0b63_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0b63_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e0b63_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0b63_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e0b63_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e0b63_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e0b63_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e0b63_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e0b63_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e0b63_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e0b63_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e0b63_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e0b63_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e0b63_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e0b63_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e0b63_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e0b63_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e0b63_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e0b63_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e0b63_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e0b63_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e0b63_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e0b63_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e0b63_row18_col1" class="data row18 col1" >536a</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e098e th {
#   text-align: left;
# }
# #T_e098e_row0_col0, #T_e098e_row0_col3, #T_e098e_row0_col4, #T_e098e_row1_col0, #T_e098e_row1_col1, #T_e098e_row1_col2, #T_e098e_row1_col3, #T_e098e_row1_col5, #T_e098e_row1_col6, #T_e098e_row1_col7, #T_e098e_row2_col0, #T_e098e_row2_col1, #T_e098e_row2_col2, #T_e098e_row2_col3, #T_e098e_row2_col4, #T_e098e_row2_col5, #T_e098e_row2_col6, #T_e098e_row2_col7, #T_e098e_row3_col0, #T_e098e_row3_col1, #T_e098e_row3_col2, #T_e098e_row3_col3, #T_e098e_row3_col4, #T_e098e_row3_col5, #T_e098e_row3_col6, #T_e098e_row3_col7, #T_e098e_row4_col0, #T_e098e_row4_col1, #T_e098e_row4_col2, #T_e098e_row4_col3, #T_e098e_row4_col4, #T_e098e_row4_col5, #T_e098e_row4_col6, #T_e098e_row4_col7, #T_e098e_row5_col0, #T_e098e_row5_col1, #T_e098e_row5_col2, #T_e098e_row5_col3, #T_e098e_row5_col4, #T_e098e_row5_col5, #T_e098e_row5_col6, #T_e098e_row5_col7, #T_e098e_row6_col0, #T_e098e_row6_col1, #T_e098e_row6_col2, #T_e098e_row6_col3, #T_e098e_row6_col4, #T_e098e_row6_col5, #T_e098e_row6_col6, #T_e098e_row6_col7, #T_e098e_row7_col0, #T_e098e_row7_col1, #T_e098e_row7_col2, #T_e098e_row7_col3, #T_e098e_row7_col4, #T_e098e_row7_col5, #T_e098e_row7_col6, #T_e098e_row7_col7, #T_e098e_row8_col0, #T_e098e_row8_col1, #T_e098e_row8_col2, #T_e098e_row8_col3, #T_e098e_row8_col4, #T_e098e_row8_col5, #T_e098e_row8_col6, #T_e098e_row8_col7, #T_e098e_row9_col0, #T_e098e_row9_col1, #T_e098e_row9_col2, #T_e098e_row9_col3, #T_e098e_row9_col4, #T_e098e_row9_col5, #T_e098e_row9_col6, #T_e098e_row9_col7, #T_e098e_row10_col0, #T_e098e_row10_col1, #T_e098e_row10_col2, #T_e098e_row10_col3, #T_e098e_row10_col4, #T_e098e_row10_col5, #T_e098e_row10_col6, #T_e098e_row10_col7, #T_e098e_row11_col0, #T_e098e_row11_col1, #T_e098e_row11_col2, #T_e098e_row11_col3, #T_e098e_row11_col4, #T_e098e_row11_col5, #T_e098e_row11_col6, #T_e098e_row11_col7, #T_e098e_row12_col0, #T_e098e_row12_col1, #T_e098e_row12_col2, #T_e098e_row12_col3, #T_e098e_row12_col4, #T_e098e_row12_col5, #T_e098e_row12_col6, #T_e098e_row12_col7, #T_e098e_row13_col0, #T_e098e_row13_col1, #T_e098e_row13_col2, #T_e098e_row13_col3, #T_e098e_row13_col4, #T_e098e_row13_col5, #T_e098e_row13_col6, #T_e098e_row13_col7, #T_e098e_row14_col0, #T_e098e_row14_col1, #T_e098e_row14_col2, #T_e098e_row14_col3, #T_e098e_row14_col4, #T_e098e_row14_col5, #T_e098e_row14_col6, #T_e098e_row14_col7, #T_e098e_row15_col0, #T_e098e_row15_col1, #T_e098e_row15_col2, #T_e098e_row15_col4, #T_e098e_row15_col5, #T_e098e_row15_col6, #T_e098e_row15_col7 {
#   text-align: left;
# }
# #T_e098e_row0_col1, #T_e098e_row0_col2, #T_e098e_row0_col5, #T_e098e_row0_col6, #T_e098e_row0_col7, #T_e098e_row1_col4, #T_e098e_row15_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e098e_row0_col8, #T_e098e_row1_col8, #T_e098e_row2_col8, #T_e098e_row3_col8, #T_e098e_row4_col8, #T_e098e_row5_col8, #T_e098e_row6_col8, #T_e098e_row7_col8, #T_e098e_row8_col8, #T_e098e_row9_col8, #T_e098e_row10_col8, #T_e098e_row11_col8, #T_e098e_row12_col8, #T_e098e_row14_col8, #T_e098e_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e098e_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e098e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e098e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e098e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e098e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e098e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e098e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e098e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e098e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e098e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e098e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e098e_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_e098e_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_e098e_row0_col1" class="data row0 col1" >0.8220</td>
#       <td id="T_e098e_row0_col2" class="data row0 col2" >0.8634</td>
#       <td id="T_e098e_row0_col3" class="data row0 col3" >0.6819</td>
#       <td id="T_e098e_row0_col4" class="data row0 col4" >0.8274</td>
#       <td id="T_e098e_row0_col5" class="data row0 col5" >0.7416</td>
#       <td id="T_e098e_row0_col6" class="data row0 col6" >0.6088</td>
#       <td id="T_e098e_row0_col7" class="data row0 col7" >0.6201</td>
#       <td id="T_e098e_row0_col8" class="data row0 col8" >0.1510</td>
#     </tr>
#     <tr>
#       <th id="T_e098e_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_e098e_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_e098e_row1_col1" class="data row1 col1" >0.8171</td>
#       <td id="T_e098e_row1_col2" class="data row1 col2" >0.8626</td>
#       <td id="T_e098e_row1_col3" class="data row1 col3" >0.6609</td>
#       <td id="T_e098e_row1_col4" class="data row1 col4" >0.8357</td>
#       <td id="T_e098e_row1_col5" class="data row1 col5" >0.7307</td>
#       <td id="T_e098e_row1_col6" class="data row1 col6" >0.5962</td>
#       <td id="T_e098e_row1_col7" class="data row1 col7" >0.6112</td>
#       <td id="T_e098e_row1_col8" class="data row1 col8" >2.0610</td>
#     </tr>
#     <tr>
#       <th id="T_e098e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_e098e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e098e_row2_col1" class="data row2 col1" >0.8057</td>
#       <td id="T_e098e_row2_col2" class="data row2 col2" >0.8506</td>
#       <td id="T_e098e_row2_col3" class="data row2 col3" >0.7152</td>
#       <td id="T_e098e_row2_col4" class="data row2 col4" >0.7664</td>
#       <td id="T_e098e_row2_col5" class="data row2 col5" >0.7374</td>
#       <td id="T_e098e_row2_col6" class="data row2 col6" >0.5838</td>
#       <td id="T_e098e_row2_col7" class="data row2 col7" >0.5870</td>
#       <td id="T_e098e_row2_col8" class="data row2 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_e098e_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_e098e_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_e098e_row3_col1" class="data row3 col1" >0.8026</td>
#       <td id="T_e098e_row3_col2" class="data row3 col2" >0.8586</td>
#       <td id="T_e098e_row3_col3" class="data row3 col3" >0.7025</td>
#       <td id="T_e098e_row3_col4" class="data row3 col4" >0.7753</td>
#       <td id="T_e098e_row3_col5" class="data row3 col5" >0.7312</td>
#       <td id="T_e098e_row3_col6" class="data row3 col6" >0.5762</td>
#       <td id="T_e098e_row3_col7" class="data row3 col7" >0.5839</td>
#       <td id="T_e098e_row3_col8" class="data row3 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_e098e_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_e098e_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_e098e_row4_col1" class="data row4 col1" >0.8010</td>
#       <td id="T_e098e_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_e098e_row4_col3" class="data row4 col3" >0.6984</td>
#       <td id="T_e098e_row4_col4" class="data row4 col4" >0.7744</td>
#       <td id="T_e098e_row4_col5" class="data row4 col5" >0.7285</td>
#       <td id="T_e098e_row4_col6" class="data row4 col6" >0.5724</td>
#       <td id="T_e098e_row4_col7" class="data row4 col7" >0.5803</td>
#       <td id="T_e098e_row4_col8" class="data row4 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_e098e_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_e098e_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_e098e_row5_col1" class="data row5 col1" >0.7962</td>
#       <td id="T_e098e_row5_col2

# %%
print(best)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=4778, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
finalize_model(best)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Pclass', 'Age', 'SibSp', 'Parch',
#                                              'Fare', 'Sex_female', 'Sex_male',
#                                              'Embarked_C', 'Embarked_Q',
#                                              'Embarked_S'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose=...
#                                             criterion='friedman_mse', init=None,
#                                             learning_rate=0.1, loss='log_loss',
#                                             max_depth=3, max_features=None,
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=100,
#                                             n_iter_no_change=None,
#                                             random_state=4778, subsample=1.0,
#                                             tol=0.0001, validation_fraction=0.1,
#                                             verbose=0, warm_start=False))],
#          verbose=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b97a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b97a5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b97a5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b97a5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b97a5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b97a5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b97a5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b97a5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b97a5_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b97a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b97a5_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b97a5_row0_col1" class="data row0 col1" >0.8470</td>
#       <td id="T_b97a5_row0_col2" class="data row0 col2" >0.8767</td>
#       <td id="T_b97a5_row0_col3" class="data row0 col3" >0.7864</td>
#       <td id="T_b97a5_row0_col4" class="data row0 col4" >0.8100</td>
#       <td id="T_b97a5_row0_col5" class="data row0 col5" >0.7980</td>
#       <td id="T_b97a5_row0_col6" class="data row0 col6" >0.6749</td>
#       <td id="T_b97a5_row0_col7" class="data row0 col7" >0.6751</td>
#     </tr>
#   </tbody>
# </table>
#        Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 502  0.841916  0.000000 -0.479087 -0.445000 -0.496263    1.344995 -1.344995
# 186  0.841916  0.000000  0.481288 -0.445000 -0.344079    1.344995 -1.344995
# 456 -1.546098  2.726986 -0.479087 -0.445000 -0.130425   -0.743497  0.743497
# 410  0.841916  0.000000 -0.479087 -0.445000 -0.491108   -0.743497  0.743497
# 145 -0.352091 -0.844922  0.481288  0.710763  0.066794   -0.743497  0.743497
# ..        ...       ...       ...       ...       ...         ...       ...
# 309 -1.546098  0.009230 -0.479087 -0.445000  0.456963    1.344995 -1.344995
# 193 -0.352091 -2.087325  0.481288  0.710763 -0.141060   -0.743497  0.743497
# 282  0.841916 -1.077873 -0.479087 -0.445000 -0.460091   -0.743497  0.743497
# 20  -0.352091  0.397481 -0.479087 -0.445000 -0.141060   -0.743497  0.743497
# 272 -0.352091  0.863382 -0.479087  0.710763 -0.266739    1.344995 -1.344995
#
#      Embarked_C  Embarked_Q  Embarked_S  Survived  prediction_label  \
# 502    -0.50977    3.105201   -1.521159         0                 1
# 186    -0.50977    3.105201   -1.521159         1                 1
# 456    -0.50977   -0.322040    0.657394         0                 0
# 410    -0.50977   -0.322040    0.657394         0                 0
# 145    -0.50977   -0.322040    0.657394         0                 0
# ..          ...         ...         ...       ...               ...
# 309     1.96167   -0.322040   -1.521159         1                 1
# 193    -0.50977   -0.322040    0.657394         1                 1
# 282    -0.50977   -0.322040    0.657394         0                 0
# 20     -0.50977   -0.322040    0.657394         0                 0
# 272    -0.50977   -0.322040    0.657394         1                 1
#
#      prediction_score
# 502            0.8646
# 186            0.7031
# 456            0.8757
# 410            0.9313
# 145            0.8494
# ..                ...
# 309            0.9761
# 193            0.9613
# 282            0.9107
# 20             0.8085
# 272            0.9524
#
# [268 rows x 13 columns]

# %%
predictions = predict_model(best, test_final)

# %%
predictions
# Out:
#        Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 0    0.841916  0.358655 -0.479087 -0.445000 -0.492396   -0.743497  0.743497
# 1    0.841916  1.329283  0.481288 -0.445000 -0.508429    1.344995 -1.344995
# 2   -0.352091  2.494035 -0.479087 -0.445000 -0.456465   -0.743497  0.743497
# 3    0.841916 -0.223721 -0.479087 -0.445000 -0.476284   -0.743497  0.743497
# 4    0.841916 -0.611972  0.481288  0.710763 -0.406194    1.344995 -1.344995
# ..        ...       ...       ...       ...       ...         ...       ...
# 413  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 414 -1.546098  0.708081 -0.479087 -0.445000  1.461829    1.344995 -1.344995
# 415  0.841916  0.669256 -0.479087 -0.445000 -0.503595   -0.743497  0.743497
# 416  0.841916  0.000000 -0.479087 -0.445000 -0.488127   -0.743497  0.743497
# 417  0.841916  0.000000  0.481288  0.710763 -0.211473   -0.743497  0.743497
#
#      Embarked_C  Embarked_Q  Embarked_S  prediction_label  prediction_score
# 0      -0.50977    3.105201   -1.521159                 0            0.8989
# 1      -0.50977   -0.322040    0.657394                 1            0.7001
# 2      -0.50977    3.105201   -1.521159                 0            0.6553
# 3      -0.50977   -0.322040    0.657394                 0            0.8161
# 4      -0.50977   -0.322040    0.657394                 0            0.6464
# ..          ...         ...         ...               ...               ...
# 413    -0.50977   -0.322040    0.657394                 0            0.9098
# 414     1.96167   -0.322040   -1.521159                 1            0.9454
# 415    -0.50977   -0.322040    0.657394                 0            0.9472
# 416    -0.50977   -0.322040    0.657394                 0            0.9098
# 417     1.96167   -0.322040   -1.521159                 0            0.8482
#
# [418 rows x 12 columns]

# %%
test_ids
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
predictions['prediction_label']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: prediction_label, Length: 418, dtype: int32

# %%
Final_Results = pd.concat([test_ids, predictions], axis =1)

# %%
Final_Results
# Out:
#      PassengerId    Pclass       Age     SibSp     Parch      Fare  \
# 0            892  0.841916  0.358655 -0.479087 -0.445000 -0.492396
# 1            893  0.841916  1.329283  0.481288 -0.445000 -0.508429
# 2            894 -0.352091  2.494035 -0.479087 -0.445000 -0.456465
# 3            895  0.841916 -0.223721 -0.479087 -0.445000 -0.476284
# 4            896  0.841916 -0.611972  0.481288  0.710763 -0.406194
# ..           ...       ...       ...       ...       ...       ...
# 413         1305  0.841916  0.000000 -0.479087 -0.445000 -0.488127
# 414         1306 -1.546098  0.708081 -0.479087 -0.445000  1.461829
# 415         1307  0.841916  0.669256 -0.479087 -0.445000 -0.503595
# 416         1308  0.841916  0.000000 -0.479087 -0.445000 -0.488127
# 417         1309  0.841916  0.000000  0.481288  0.710763 -0.211473
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S  \
# 0     -0.743497  0.743497    -0.50977    3.105201   -1.521159
# 1      1.344995 -1.344995    -0.50977   -0.322040    0.657394
# 2     -0.743497  0.743497    -0.50977    3.105201   -1.521159
# 3     -0.743497  0.743497    -0.50977   -0.322040    0.657394
# 4      1.344995 -1.344995    -0.50977   -0.322040    0.657394
# ..          ...       ...         ...         ...         ...
# 413   -0.743497  0.743497    -0.50977   -0.322040    0.657394
# 414    1.344995 -1.344995     1.96167   -0.322040   -1.521159
# 415   -0.743497  0.743497    -0.50977   -0.322040    0.657394
# 416   -0.743497  0.743497    -0.50977   -0.322040    0.657394
# 417   -0.743497  0.743497     1.96167   -0.322040   -1.521159
#
#      prediction_label  prediction_score
# 0                   0            0.8989
# 1                   1            0.7001
# 2                   0            0.6553
# 3                   0            0.8161
# 4                   0            0.6464
# ..                ...               ...
# 413                 0            0.9098
# 414                 1            0.9454
# 415                 0            0.9472
# 416                 0            0.9098
# 417                 0            0.8482
#
# [418 rows x 13 columns]

# %%
submission = Final_Results[['PassengerId', 'prediction_label']].copy()

# Rename the column
submission = submission.rename(columns={'prediction_label': 'survived'})

# Reset the indexes
submission.reset_index(drop=True, inplace=True)

# %%
submission
# Out:
#      PassengerId  survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission.to_csv('C:\\Users\\Auditor\\Desktop\\Victor\\New folder\\Data Science\\Projects\\Final_submissionTitanic2.csv'
, index=False, header=True)
